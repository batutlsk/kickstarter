# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
data=pd.read_csv('data/ks-projects-201801.csv')

# %%
data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %%
data.columns.values
# Out:
# array(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'goal', 'launched', 'pledged', 'state', 'backers', 'country',
#        'usd pledged', 'usd_pledged_real', 'usd_goal_real'], dtype=object)

# %%
data['usd_pledged_real']
# Out:
# 0              0.00
# 1           2421.00
# 2            220.00
# 3              1.00
# 4           1283.00
# 5          52375.00
# 6           1205.00
# 7            453.00
# 8           8233.00
# 9           6240.57
# 10             0.00
# 11         12700.00
# 12             0.00
# 13             0.00
# 14        121857.33
# 15           664.00
# 16           395.00
# 17           789.00
# 18           250.00
# 19          1781.00
# 20         34268.00
# 21             0.81
# 22           650.00
# 23             6.29
# 24           701.66
# 25         15827.00
# 26             0.00
# 27         42174.03
# 28           160.60
# 29         57577.31
#             ...
# 378631     13861.50
# 378632         0.00
# 378633     11643.00
# 378634      3531.00
# 378635        70.00
# 378636      4686.96
# 378637     10245.00
# 378638        18.00
# 378639      5579.00
# 378640       100.00
# 378641         0.00
# 378642      1452.47
# 378643         0.00
# 378644      6169.00
# ...

# %%
data['usd_pledged_real'].mean()
# Out:
# 9058.92407411907

# %%
data['usd_pledged_real'].describe()
# Out:
# count    3.786610e+05
# mean     9.058924e+03
# std      9.097334e+04
# min      0.000000e+00
# 25%      3.100000e+01
# 50%      6.243300e+02
# 75%      4.050000e+03
# max      2.033899e+07
# Name: usd_pledged_real, dtype: float64

# %%
data['category'].describe()
# Out:
# count             378661
# unique               159
# top       Product Design
# freq               22314
# Name: category, dtype: object

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbba85da550>,
# ...
#       dtype=object)

# %%
# %matplotlib inline

# %%
data['usd_pledged_real'].hist(by=data['state'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbba60d52b0>,
# ...
#       dtype=object)

# %%
data2=data[['category','usd_pledged_real']]

# %%
data2g=data2.groupby('category').sum()

# %%
data2g.iloc[1:5].plot.line(fontsize=6)

# %%
data2g
# Out:
#                    usd_pledged_real
# category
# 3D Printing            4.529920e+07
# Academic               2.648169e+06
# Accessories            2.065572e+07
# Action                 2.737575e+06
# Animals                7.635236e+05
# Animation              2.527167e+07
# Anthologies            7.723628e+06
# Apparel                3.915006e+07
# Apps                   1.040834e+07
# Architecture           4.867253e+06
# Art                    2.957298e+07
# Art Books              2.388385e+07
# Audio                  1.446415e+06
# Bacon                  3.111150e+05
# Blues                  1.071763e+06
# Calendars              1.274056e+06
# Camera Equipment       3.384673e+07
# Candles                2.418885e+05
# Ceramics               1.435291e+06
# Children's Books       2.396554e+07
# Childrenswear          1.683263e+06
# Chiptune               6.192034e+05
# Civic Design           3.315001e+06
# Classical Music        1.207716e+07
# Comedy                 1.413637e+07
# ...

# %%
data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %%
data.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  3.786610e+05  3.786610e+05  3.786610e+05  378661.000000  3.748640e+05
# mean   1.074731e+09  4.908079e+04  9.682979e+03     105.617476  7.036729e+03
# std    6.190862e+08  1.183391e+06  9.563601e+04     907.185035  7.863975e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.382635e+08  2.000000e+03  3.000000e+01       2.000000  1.698000e+01
# 50%    1.075276e+09  5.200000e+03  6.200000e+02      12.000000  3.947200e+02
# 75%    1.610149e+09  1.600000e+04  4.076000e+03      56.000000  3.034090e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.786610e+05   3.786610e+05
# mean       9.058924e+03   4.545440e+04
# std        9.097334e+04   1.152950e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# ...

# %%
ham_veri_desc=data.describe()

# %%
ham_veri_des
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-279afabaa411> in <module>()
# ----> 1 ham_veri_des
#
# NameError: name 'ham_veri_des' is not defined

# %%
#outlier check for usd_goal_real
fl=ham_veri_desc.iloc[4,6]
fu=ham_veri_desc.iloc[6,6]
df=fu-fl
lowlim=fl-1.5*df
uplim=fu+1.5*df
outliers=(data.iloc[:,14]>uplim) #lowlim negatif çıktığından
outliers.value_counts()

# %%
fl
fu
df
lowlim
uplim
outliers

# %%
#backers başına ort usd_goal_real
back_avg=data.iloc[:,14].sum()/data.iloc[:,10].sum()
back_avg

# %%
data1=data.iloc[:,]

# %%
data1= data[data["state"]=="successful"]
data1
# Out:
#                 ID                                               name  \
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 11       100005484                                   Lisa Lim New CD!
# 14      1000057089  Tombstone: Old West tabletop game and miniatur...
# 18      1000070642                Mike Corey's Darkness & Light Album
# 20      1000072011              CMUK. Shoes: Take on Life Feet First.
# 24      1000091520                        The Book Zoo - A Mini-Comic
# 25      1000102741  Matt Cavenaugh & Jenny Powers make their 1st a...
# 27      1000104688                                Permaculture Skills
# 28      1000104953  Rebel Army Origins: The Heroic Story Of Major ...
# 29       100011318                      My Moon - Animated Short Film
# 31      1000117861                  Ledr workbook: one tough journal!
# ...

# %%
data2=data1[['main_category','category','usd_goal_real','backers']]
data2_groupedby_category= data2.groupby(["main_category","category"]).describe()
data2_groupedby_category
# Out:
#                                 backers                                  \
#                                   count         mean          std   min
# main_category category
# Art           Art                3385.0    94.994092   300.552217   1.0
#               Ceramics            132.0   100.886364   140.899490   4.0
#               Conceptual Art      366.0    61.535519   119.983778   1.0
#               Digital Art         371.0   102.444744   227.817350   1.0
#               Illustration       1626.0   115.496310   305.262061   1.0
#               Installations       233.0    86.364807   125.765244   1.0
#               Mixed Media         945.0    73.485714   210.187810   1.0
#               Painting           1149.0    53.557876   112.432292   1.0
#               Performance Art     934.0    61.169165    75.487819   1.0
#               Public Art         1543.0   110.589760   600.384123   1.0
#               Sculpture           698.0    98.435530   397.937292   1.0
# ...

# %%
a=data2_groupedby_category["backers"]["mean"]
a
# Out:
# main_category  category
# Art            Art                    94.994092
#                Ceramics              100.886364
#                Conceptual Art         61.535519
#                Digital Art           102.444744
#                Illustration          115.496310
#                Installations          86.364807
#                Mixed Media            73.485714
#                Painting               53.557876
#                Performance Art        61.169165
#                Public Art            110.589760
#                Sculpture              98.435530
#                Textiles               77.584416
#                Video Art              64.019608
# Comics         Anthologies           374.217822
#                Comic Books           134.017348
#                Comics                236.938148
#                Events                134.480000
#                Graphic Novels        260.783383
#                Webcomics             441.421788
# ...

# %%
b=data2_groupedby_category["usd_goal_real"]["mean"]
b
# Out:
# main_category  category
# Art            Art                   4982.917935
#                Ceramics              7137.972803
#                Conceptual Art        3087.916475
#                Digital Art           3462.291968
#                Illustration          2548.473044
#                Installations         6736.158970
#                Mixed Media           3759.823481
#                Painting              3069.567293
#                Performance Art       4019.823833
#                Public Art            6389.689559
#                Sculpture             5036.445530
#                Textiles              4406.586234
#                Video Art             5375.607843
# Comics         Anthologies           8558.659274
#                Comic Books           2947.210936
#                Comics                5315.063001
#                Events                6541.420200
#                Graphic Novels        7499.459881
#                Webcomics             8247.727291
# ...

# %%
z=b/a
z
# Out:
# main_category  category
# Art            Art                  52.455030
#                Ceramics             70.752603
#                Conceptual Art       50.181042
#                Digital Art          33.796677
#                Illustration         22.065407
#                Installations        77.996573
#                Mixed Media          51.164005
#                Painting             57.313088
#                Performance Art      65.716507
#                Public Art           57.778311
#                Sculpture            51.164915
#                Textiles             56.797312
#                Video Art            83.968147
# Comics         Anthologies          22.870795
#                Comic Books          21.991264
#                Comics               22.432280
#                Events               48.642327
#                Graphic Novels       28.757430
#                Webcomics            18.684459
# Crafts         Candles              29.729857
# ...

# %%
z[z==z.max()]
# Out:
# main_category  category
# Food           Restaurants    111.296629
# Name: mean, dtype: float64

# %%
z[z==z.min()]
# Out:
# main_category  category
# Publishing     Comedy      10.727782
# Name: mean, dtype: float64

# %%
z
# Out:
# main_category  category
# Art            Art                  52.455030
#                Ceramics             70.752603
#                Conceptual Art       50.181042
#                Digital Art          33.796677
#                Illustration         22.065407
#                Installations        77.996573
#                Mixed Media          51.164005
#                Painting             57.313088
#                Performance Art      65.716507
#                Public Art           57.778311
#                Sculpture            51.164915
#                Textiles             56.797312
#                Video Art            83.968147
# Comics         Anthologies          22.870795
#                Comic Books          21.991264
#                Comics               22.432280
#                Events               48.642327
#                Graphic Novels       28.757430
#                Webcomics            18.684459
# Crafts         Candles              29.729857
# ...

# %%
ax = z.plot.line(subplots=True)  # s is an instance of Series

fig = ax[0].get_figure()

fig.savefig('figure.pdf')

# %%
z/ data1[""]
# Out:
# main_category  category
# Art            Art                  52.455030
#                Ceramics             70.752603
#                Conceptual Art       50.181042
#                Digital Art          33.796677
#                Illustration         22.065407
#                Installations        77.996573
#                Mixed Media          51.164005
#                Painting             57.313088
#                Performance Art      65.716507
#                Public Art           57.778311
#                Sculpture            51.164915
#                Textiles             56.797312
#                Video Art            83.968147
# Comics         Anthologies          22.870795
#                Comic Books          21.991264
#                Comics               22.432280
#                Events               48.642327
#                Graphic Novels       28.757430
#                Webcomics            18.684459
# Crafts         Candles              29.729857
# ...

# %%
x=z/133956

# %%
data2_groupedby_category["backers"]["count"].sum()
# Out:
# 133956.0

# %%
x
# Out:
# main_category  category
# Art            Art                  0.000392
#                Ceramics             0.000528
#                Conceptual Art       0.000375
#                Digital Art          0.000252
#                Illustration         0.000165
#                Installations        0.000582
#                Mixed Media          0.000382
#                Painting             0.000428
#                Performance Art      0.000491
#                Public Art           0.000431
#                Sculpture            0.000382
#                Textiles             0.000424
#                Video Art            0.000627
# Comics         Anthologies          0.000171
#                Comic Books          0.000164
#                Comics               0.000167
#                Events               0.000363
#                Graphic Novels       0.000215
#                Webcomics            0.000139
# Crafts         Candles              0.000222
# ...

# %%
x.plot()

# %%
x[x==x.max()]
# Out:
# main_category  category
# Food           Restaurants    0.000831
# Name: mean, dtype: float64

# %%
x.max()*133956
# Out:
# 111.29662899009608

# %%
#Make a random array and then make it positive-definite
num_vars = 6
num_obs = 9
A = data1
A = np.asmatrix(A.T) * np.asmatrix(A)
U, S, V = np.linalg.svd(A) 
eigvals = S**2 / np.cumsum(S)[-1]

fig = plt.figure(figsize=(8,5))
sing_vals = np.arange(num_vars) + 1
plt.plot(sing_vals, eigvals, 'ro-', linewidth=2)
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Eigenvalue')
#I don't like the default legend so I typically make mine like below, e.g.
#with smaller fonts and a bit transparent so I do not cover up data, and make
#it moveable by the viewer in case upper-right is a bad place for it 
leg = plt.legend(['Eigenvalues from SVD'], loc='best', borderpad=0.3, 
                 shadow=False, prop=matplotlib.font_manager.FontProperties(size='small'),
                 markerscale=0.4)
leg.get_frame().set_alpha(0.4)
leg.draggable(state=True)
plt.show()

# %%
A
# Out:
# matrix([[10.80538666,  3.10697828, -2.79483324, -0.67730624,  3.51713345,
#           1.95356474],
#         [ 3.10697828,  9.12767529, -5.24742492, -0.66387349,  3.84611629,
#          -0.6493617 ],
#         [-2.79483324, -5.24742492,  8.28629797,  1.56169334, -0.0108135 ,
#          -1.54617032],
#         [-0.67730624, -0.66387349,  1.56169334, 10.18347897,  2.93029113,
#           3.38017155],
#         [ 3.51713345,  3.84611629, -0.0108135 ,  2.93029113,  4.83535518,
#           0.61858402],
#         [ 1.95356474, -0.6493617 , -1.54617032,  3.38017155,  0.61858402,
#           6.56543615]])

# %%
A
# Out:
# matrix([[10.80538666,  3.10697828, -2.79483324, -0.67730624,  3.51713345,
#           1.95356474],
#         [ 3.10697828,  9.12767529, -5.24742492, -0.66387349,  3.84611629,
#          -0.6493617 ],
#         [-2.79483324, -5.24742492,  8.28629797,  1.56169334, -0.0108135 ,
#          -1.54617032],
#         [-0.67730624, -0.66387349,  1.56169334, 10.18347897,  2.93029113,
#           3.38017155],
#         [ 3.51713345,  3.84611629, -0.0108135 ,  2.93029113,  4.83535518,
#           0.61858402],
#         [ 1.95356474, -0.6493617 , -1.54617032,  3.38017155,  0.61858402,
#           6.56543615]])
