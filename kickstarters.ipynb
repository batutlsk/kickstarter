# %%
import pandas as pd
data=pd.read_csv('data/ks-projects-201801.csv')

# %%
data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %%
data.columns.values
# Out:
# array(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'goal', 'launched', 'pledged', 'state', 'backers', 'country',
#        'usd pledged', 'usd_pledged_real', 'usd_goal_real'], dtype=object)

# %%
data['usd_pledged_real']
# Out:
# 0              0.00
# 1           2421.00
# 2            220.00
# 3              1.00
# 4           1283.00
# 5          52375.00
# 6           1205.00
# 7            453.00
# 8           8233.00
# 9           6240.57
# 10             0.00
# 11         12700.00
# 12             0.00
# 13             0.00
# 14        121857.33
# 15           664.00
# 16           395.00
# 17           789.00
# 18           250.00
# 19          1781.00
# 20         34268.00
# 21             0.81
# 22           650.00
# 23             6.29
# 24           701.66
# 25         15827.00
# 26             0.00
# 27         42174.03
# 28           160.60
# 29         57577.31
#             ...
# 378631     13861.50
# 378632         0.00
# 378633     11643.00
# 378634      3531.00
# 378635        70.00
# 378636      4686.96
# 378637     10245.00
# 378638        18.00
# 378639      5579.00
# 378640       100.00
# 378641         0.00
# 378642      1452.47
# 378643         0.00
# 378644      6169.00
# ...

# %%
data['usd_pledged_real'].mean()
# Out:
# 9058.924074119337

# %%
data['usd_pledged_real'].describe()
# Out:
# count    3.786610e+05
# mean     9.058924e+03
# std      9.097334e+04
# min      0.000000e+00
# 25%      3.100000e+01
# 50%      6.243300e+02
# 75%      4.050000e+03
# max      2.033899e+07
# Name: usd_pledged_real, dtype: float64

# %%
data['category'].describe()
# Out:
# count             378661
# unique               159
# top       Product Design
# freq               22314
# Name: category, dtype: object

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d6f518ef0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d672d8a90>]], dtype=object)

# %%
# %matplotlib inline

# %%
data['usd_pledged_real'].hist(by=data['state'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3d67206f98>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3d670f5358>]], dtype=object)

# %%
data2=data[['category','usd_pledged_real']]

# %%
data2g=data2.groupby('category').sum()

# %%
data2g.iloc[1:5].plot.line(fontsize=6)

# %%
data2g
# Out:
#                    usd_pledged_real
# category
# 3D Printing            4.529920e+07
# Academic               2.648169e+06
# Accessories            2.065572e+07
# Action                 2.737575e+06
# Animals                7.635236e+05
# Animation              2.527167e+07
# Anthologies            7.723628e+06
# Apparel                3.915006e+07
# Apps                   1.040834e+07
# Architecture           4.867253e+06
# Art                    2.957298e+07
# Art Books              2.388385e+07
# Audio                  1.446415e+06
# Bacon                  3.111150e+05
# Blues                  1.071763e+06
# Calendars              1.274056e+06
# Camera Equipment       3.384673e+07
# Candles                2.418885e+05
# Ceramics               1.435291e+06
# Children's Books       2.396554e+07
# Childrenswear          1.683263e+06
# Chiptune               6.192034e+05
# Civic Design           3.315001e+06
# Classical Music        1.207716e+07
# Comedy                 1.413637e+07
# ...

# %%
data
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# 7       1000030581  Chaser Strips. Our Strips make Shots their B*tch!
# 8       1000034518  SPIN - Premium Retractable In-Ear Headphones w...
# 9        100004195  STUDIO IN THE SKY - A Documentary Feature Film...
# 10       100004721                                Of Jesus and Madmen
# 11       100005484                                   Lisa Lim New CD!
# ...

# %%
data.describe()
# Out:
#                  ID          goal       pledged        backers   usd pledged  \
# count  3.786610e+05  3.786610e+05  3.786610e+05  378661.000000  3.748640e+05
# mean   1.074731e+09  4.908079e+04  9.682979e+03     105.617476  7.036729e+03
# std    6.190862e+08  1.183391e+06  9.563601e+04     907.185035  7.863975e+04
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    5.382635e+08  2.000000e+03  3.000000e+01       2.000000  1.698000e+01
# 50%    1.075276e+09  5.200000e+03  6.200000e+02      12.000000  3.947200e+02
# 75%    1.610149e+09  1.600000e+04  4.076000e+03      56.000000  3.034090e+03
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.786610e+05   3.786610e+05
# mean       9.058924e+03   4.545440e+04
# std        9.097334e+04   1.152950e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# ...

# %%
ham_veri_desc=data.describe()

# %%
ham_veri_des
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-24f96308a63f> in <module>()
# ----> 1 ham_veri_des
#
# NameError: name 'ham_veri_des' is not defined

# %%
#outlier check for usd_goal_real
fl=ham_veri_desc.iloc[4,6]
fu=ham_veri_desc.iloc[6,6]
df=fu-fl
lowlim=fl-1.5*df
uplim=fu+1.5*df
outliers=(data.iloc[:,14]>uplim) #lowlim negatif çıktığından
outliers.value_counts()
# Out:
# False    333153
# True      45508
# Name: usd_goal_real, dtype: int64

# %%
fl
fu
df
lowlim
uplim
outliers

# %%
#backers başına ort usd_goal_real
back_avg=data.iloc[:,14].sum()/data.iloc[:,10].sum()
back_avg
# Out:
# 430.3681859994825

# %%
data1=data.iloc[:,]
