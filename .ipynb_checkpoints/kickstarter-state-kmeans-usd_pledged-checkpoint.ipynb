# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


data=pd.read_csv("/home/elci/repos/kickstarter/data/ks-projects-201801.csv")
data
# Out:
# /home/elci/repos/kickstarter/venv/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/elci/repos/kickstarter/venv/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# 5       1000014025                               Monarch Espresso Bar
# 6       1000023410  Support Solar Roasted Coffee & Green Energy!  ...
# ...

# %%
data.boxplot()

# %%
#outlier check for backers
data3=data.describe()
fl=data3.iloc[4,3]
fu=data3.iloc[6,3]
df=fu-fl
lowlim=fl-2*df
uplim=fu+2*df
outliers=data[data['backers']>uplim]
no_outlier=data[data['backers']<uplim]
data=no_outlier

# %%
#outlier check for "usd_pledged_real"
data3=data.describe()
fl=data3.iloc[4,6]
fu=data3.iloc[6,6]
df=fu-fl
lowlim=fl-2*df
uplim=fu+2*df
outliers=data[data["usd_pledged_real"]>uplim]
no_outlier=data[data["usd_pledged_real"]<uplim]
data=no_outlier

# %%
backers=data.iloc[:,11]
backers=pd.DataFrame(backers)
backers.boxplot()

# %%
usd_pledged=data.iloc[:,14]
usd_pledged=pd.DataFrame(usd_pledged)
usd_pledged.boxplot()

# %%
df1 = data[["backers","usd_pledged_real"]]
df= df1.iloc[1:1500,:]
df.columns=["x","y"]

np.random.seed(200)
k = 3
# centroids[i] = [x, y]
centroids = {
    i+1: [np.random.randint(0, 500), np.random.randint(0, 500)]
    for i in range(k)
}
    
fig = plt.figure(figsize=(70, 70))
plt.scatter(df['x'], df['y'], color='k')
colmap = {1: 'r', 2: 'g', 3: 'b'}
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])

plt.show()

# %%
## Assignment Stage

def assignment(df, centroids):
    for i in centroids.keys():
        # sqrt((x1 - x2)^2 - (y1 - y2)^2)
        df['distance_from_{}'.format(i)] = (
            np.sqrt(
                (df['x'] - centroids[i][0]) ** 2
                + (df['y'] - centroids[i][1]) ** 2
            )
        )
    centroid_distance_cols = ['distance_from_{}'.format(i) for i in centroids.keys()]
    df['closest'] = df.loc[:, centroid_distance_cols].idxmin(axis=1)
    df['closest'] = df['closest'].map(lambda x: int(x.lstrip('distance_from_')))
    df['color'] = df['closest'].map(lambda x: colmap[x])
    return df

df = assignment(df, centroids)
print(df.head())

fig = plt.figure(figsize=(5, 5))
plt.scatter(df['x'], df['y'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])

plt.show()
# Out:
# /home/elci/repos/kickstarter/venv/lib/python3.5/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/elci/repos/kickstarter/venv/lib/python3.5/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/elci/repos/kickstarter/venv/lib/python3.5/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
## Update Stage

import copy

old_centroids = copy.deepcopy(centroids)

def update(k):
    for i in centroids.keys():
        centroids[i][0] = np.mean(df[df['closest'] == i]['x'])
        centroids[i][1] = np.mean(df[df['closest'] == i]['y'])
    return k

centroids = update(centroids)
    
fig = plt.figure(figsize=(5, 5))
ax = plt.axes()
plt.scatter(df['x'], df['y'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i])

for i in old_centroids.keys():
    old_x = old_centroids[i][0]
    old_y = old_centroids[i][1]
    dx = (centroids[i][0] - old_centroids[i][0]) * 0.75
    dy = (centroids[i][1] - old_centroids[i][1]) * 0.75
    ax.arrow(old_x, old_y, dx, dy, head_width=2, head_length=3, fc=colmap[i], ec=colmap[i])
plt.show()

# %%
## Repeat Assigment Stage

df = assignment(df, centroids)

# Plot results
fig = plt.figure(figsize=(20, 20))
plt.scatter(df['y'], df['x'], color=df['color'], alpha=0.5, edgecolor='k')
for i in centroids.keys():
    plt.scatter(*centroids[i], color=colmap[i],s=0.005)
#plt.xlim(0, 80)
plt.ylim(0, 200)
fig.savefig('"backers","usd_pledged_real".pdf')
plt.show()
# Out:
# /home/elci/repos/kickstarter/venv/lib/python3.5/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /home/elci/repos/kickstarter/venv/lib/python3.5/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]
# /home/elci/repos/kickstarter/venv/lib/python3.5/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df
# Out:
#         x         y  distance_from_1  distance_from_2  distance_from_3  \
# 1      15   2421.00      2383.134795      1545.603467      2218.850225
# 2       3    220.00       182.102130      3746.554528        20.967177
# 3       1      1.00        36.911651      3965.563305       201.569647
# 4      14   1283.00      1245.157705      2683.497916      1080.850000
# 6      16   1205.00      1167.184149      2761.472017      1002.851994
# 7      40    453.00       416.846112      3513.330961       252.193819
# 8      58   8233.00      8195.290844      4266.693964      8030.970534
# 9      43   6240.57      6202.804989      2274.241786      6038.489637
# 10      0      0.00        37.947530      3966.574251       202.634209
# 11    100  12700.00     12662.478865      8733.850049     12498.145887
# 12      0      0.00        37.947530      3966.574251       202.634209
# 13      0      0.00        37.947530      3966.574251       202.634209
# ...

# %%
df[df["closest"]==1].describe()
# Out:
#                 x           y  distance_from_1  distance_from_2  \
# count  547.000000  547.000000       547.000000       547.000000
# mean     1.420475   21.260512        32.630461      3945.299849
# std      2.022443   31.703672        14.837279        31.714916
# min      0.000000    0.000000         1.905728      3846.527774
# 25%      0.000000    0.000000        22.909832      3935.564218
# 50%      1.000000    2.000000        37.947530      3964.552606
# 75%      2.000000   30.985000        37.947530      3966.574251
# max     18.000000  120.000000        82.158230      3966.574251
#
#        distance_from_3  closest
# count       547.000000    547.0
# mean        181.340137      1.0
# std          31.689272      0.0
# min          82.641530      1.0
# 25%         171.613095      1.0
# 50%         200.509408      1.0
# 75%         202.634209      1.0
# max         202.634209      1.0

# %%
df[df["closest"]==2].describe()
# Out:
#                 x             y  distance_from_1  distance_from_2  \
# count  428.000000    428.000000       428.000000       428.000000
# mean    69.212617   7184.371215      7146.970135      3990.840105
# std     38.430803   6287.483924      6287.392855      5826.706425
# min      0.000000   2095.000000      2057.451964        21.899039
# 25%     40.000000   3188.312500      3152.095903       836.786329
# 50%     62.000000   5000.000000      4962.336970      1537.932241
# 75%     94.000000   8902.877500      8865.388093      4936.781355
# max    161.000000  40062.000000     40024.264214     36095.745003
#
#        distance_from_3  closest
# count       428.000000    428.0
# mean       6982.597179      2.0
# std        6287.425866      0.0
# min        1893.028558      2.0
# 25%        2987.579470      2.0
# 50%        4797.990165      2.0
# 75%        8701.043631      2.0
# max       39859.983079      2.0

# %%
df[df["closest"]==3].describe()
# Out:
#                 x            y  distance_from_1  distance_from_2  \
# count  524.000000   524.000000       524.000000       524.000000
# mean    18.125954   793.260725       755.628196      3173.205394
# std     15.456699   555.378150       555.465150       555.416502
# min      0.000000   125.000000        87.098727      1883.649455
# 25%      7.000000   300.750000       263.012717      2770.548691
# 50%     14.000000   643.500000       606.206696      3322.939367
# 75%     25.000000  1195.830000      1158.212562      3665.728833
# max     89.000000  2082.740000      2045.018582      3841.559781
#
#        distance_from_3  closest
# count       524.000000    524.0
# mean        603.295836      3.0
# std         542.327438      0.0
# min           0.000000      3.0
# 25%          98.830120      3.0
# 50%         441.770014      3.0
# 75%         993.772089      3.0
# max        1880.649821      3.0

# %%
df
# Out:
#         x         y  distance_from_1  distance_from_2  distance_from_3  \
# 1      15   2421.00      2383.134795      1545.603467      2218.850225
# 2       3    220.00       182.102130      3746.554528        20.967177
# 3       1      1.00        36.911651      3965.563305       201.569647
# 4      14   1283.00      1245.157705      2683.497916      1080.850000
# 6      16   1205.00      1167.184149      2761.472017      1002.851994
# 7      40    453.00       416.846112      3513.330961       252.193819
# 8      58   8233.00      8195.290844      4266.693964      8030.970534
# 9      43   6240.57      6202.804989      2274.241786      6038.489637
# 10      0      0.00        37.947530      3966.574251       202.634209
# 11    100  12700.00     12662.478865      8733.850049     12498.145887
# 12      0      0.00        37.947530      3966.574251       202.634209
# 13      0      0.00        37.947530      3966.574251       202.634209
# ...
